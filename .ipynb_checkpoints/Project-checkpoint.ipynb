# %% [markdown]
# #                              Deep Learning - Final Project
#
# ###                                  *Trinidad Bosch*
# ###                                  *Sarah Einhaus*
#
# ###      The Simpsons - Project Description
#
# Our project is based on a dataset of dialogue lines from the 27 first seasons of 'The Simpsons', accessible under the following link: *https://www.kaggle.com/datasets/pierremegret/dialogue-lines-of-the-simpsons?resource=download*
#
# One of the main goals is to see if we can build a model that is able to identify which sentence has been uttered by which character and then predict exactly this. As you will be able to see throughout the project, this is a rather challenging task and different models we built end up at accuracies of around 40%, which is an okay performance given the fact that dialogues usually cover one topic and hence the utterances of individual characters must obviously be relatively similar in order to just form a pragmatically felicitous conversation. However, we wanted to see if there maybe are some inter-individual differences between the speakers that stand out and may be characteristic and unique enough to be detected, modeled and predicted by a neural network.
#
# It is important to note however, that the first part of our project is in many ways similar to the Big Bang Theory Lab Session and we have no intention of hiding this and hereby give full credit to this particular tutorial. We honestly had the idea of this Simpsons-Project before talking about the Big Bang Theory Analysis in class and thought of changing our project after the Lab Session, but ended up deciding against that because we thought we could use this source as a foundation to build on and extend in our second part and hence make the whole project even more extensive.
# This is why in the second part, and hence kind of our main part, we focus on exactly this extension and try building the model with CLS embeddings and later on try to see what kind of results we get when applying a neural network in an unsupervised way to see if we then get better results by clustering with different algorithms. More information and description of our steps is provided throughout the project.
# ___________

# %% [markdown]
# # Step 1: Dataset Analysis and Manipulation
# - drop null values
# - look at the data and make decisions in terms of filtering
#
# As we will work with pretrained bert models, there is no need for much NLP preprocessing.

# %% [markdown]
# The dataset contains the lines of the 27 first seasons of 'The Simpsons'. It contains 2 columns: character and spoken words.

# %%
import pandas as pd #for data handling
import re #for preprocessing
import time #to check time of operations
import matplotlib.pyplot as mp #for visualization
from tqdm import tqdm # for running process

# %%
#Import dataset 
df = pd.read_csv (r'simpsons_dataset.csv')
df.head()
# Out:
#         raw_character_text                                       spoken_words
# 0              Miss Hoover  No, actually, it was a little of both. Sometim...
# 1             Lisa Simpson                             Where's Mr. Bergstrom?
# 2              Miss Hoover  I don't know. Although I'd sure like to talk t...
# 3             Lisa Simpson                         That life is worth living.
# 4  Edna Krabappel-Flanders  The polls will be open from now until the end ...

# %%
#Renaming columns for better use
df.rename(columns = {'raw_character_text':'character', 'spoken_words':'text'}, inplace = True)
df.head()
# Out:
#                  character                                               text
# 0              Miss Hoover  No, actually, it was a little of both. Sometim...
# 1             Lisa Simpson                             Where's Mr. Bergstrom?
# 2              Miss Hoover  I don't know. Although I'd sure like to talk t...
# 3             Lisa Simpson                         That life is worth living.
# 4  Edna Krabappel-Flanders  The polls will be open from now until the end ...

# %%
#Check if there are null in the data set
df.isnull().sum()
# Out:
# character    17814
# text         26459
# dtype: int64

# %%
#Dropping null values before text preprocessing
df = df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# character    0
# text         0
# dtype: int64

# %% [markdown]
# >Before doing any preprocessing we wanted to have a look on the most important characters of the serie, therefore decided to  filter the dataset and work with those characters that have more than 500 dialogue lines.

# %%
#Check the % count of the dialogues of each character
df.character.value_counts()
print(df.character.value_counts(normalize=True)*100)
# Out:
# Homer Simpson          21.122007
# Marge Simpson           9.989913
# Bart Simpson            9.855673
# Lisa Simpson            8.157569
# C. Montgomery Burns     2.333659
#                          ...
# Hillbilly               0.000758
# Lucius Sweet            0.000758
# Dennis Hopper           0.000758
# Prince Charles          0.000758
# Moes                    0.000758
# Name: character, Length: 6272, dtype: float64

# %%
df['character'].value_counts()[:20].plot(kind='bar') #plotting the %-count of characters that contribute most data
# Out:
# <AxesSubplot:>

# %% [markdown]
# 50% of the total lines dialogues corresponds to the Simpson family where Homer contributes 20% of the total. To have a more meaningful analysis we decided to work with those characters where the count of dialogues is above 1000.

# %%
#creating a column that stores the count of each character in the data set 
df['count'] = df.groupby(['character'])['character'].transform('count')

#Filter those characters that have a count of 1000 or more
final_df = df.loc[df['count'] >= 1000]

# %%
len_ = len(final_df['text'])
len_1 = len(df['text'])
print('-------')
print(f'We will work with {len_} dialogues which corresponds to a {format(((len_/len_1)*100),".2f")} % of the original dataset') 
print('-------')
# Out:
# -------
# We will work with 84427 dialogues which corresponds to a 64.03 % of the original dataset
# -------

# %% [markdown]
# ____________________________________________
# # Step 2: Extracting contextualized Embeddings
# In this step we extract the contextualized embeddings for the characters we decided to work with in the previous step.
#
# **Footnote about embeddings**
#
# We extracted embeddings for Neural Network and also for clustering and in some of the multiple iterations we had error while running the functions and on other iterations we did not, we are not sure if is because we worked on the server.
#
# Two options work for extracting them work with no problem:
# 1. Extract them before continue with any task, so run the first 'embeddings1', then go to the Second Part of this project and run 'embeddings2', and then continue with the NN and the Clustering task.
# 2. Run the first embeddings and continue with the whole task, then restar the kernel and run embeddings2 and continue with Clustering task.
#
# __________________

# %%
pip install -U sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sentence-transformers in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/lib64/python3.6/site-packages (from sentence-transformers) (0.23.2)
# Requirement already satisfied: sentencepiece in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from sentence-transformers) (0.1.97)
# Requirement already satisfied: torchvision in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from sentence-transformers) (0.11.2)
# Requirement already satisfied: nltk in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from sentence-transformers) (3.6.7)
# Requirement already satisfied: tqdm in /usr/lib/python3.6/site-packages (from sentence-transformers) (4.45.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from sentence-transformers) (4.18.0)
# Requirement already satisfied: torch>=1.6.0 in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: scipy in /usr/lib64/python3.6/site-packages (from sentence-transformers) (1.3.3)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from sentence-transformers) (0.4.0)
# Requirement already satisfied: numpy in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from sentence-transformers) (1.19.5)
# Requirement already satisfied: requests in /usr/lib/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.26.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.7.4.3)
# Requirement already satisfied: importlib-metadata in /usr/lib/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.6.3)
# Requirement already satisfied: filelock in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.4.1)
# Requirement already satisfied: packaging>=20.9 in /usr/lib/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.0)
# Requirement already satisfied: pyyaml in /usr/lib64/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (5.4.1)
# Requirement already satisfied: dataclasses in /usr/lib/python3.6/site-packages (from torch>=1.6.0->sentence-transformers) (0.8)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.12.1)
# Requirement already satisfied: sacremoses in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.0.53)
# Requirement already satisfied: regex!=2019.12.17 in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.6.2)
# Requirement already satisfied: joblib in /usr/lib/python3.6/site-packages (from nltk->sentence-transformers) (0.16.0)
# Requirement already satisfied: click in /usr/lib/python3.6/site-packages (from nltk->sentence-transformers) (7.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/lib64/python3.6/site-packages (from torchvision->sentence-transformers) (8.3.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/lib/python3.6/site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3.6/site-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3.6/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3.6/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.6/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/lib/python3.6/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: six in /export/home/sarah.einhaus/.local/lib/python3.6/site-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing all necessary modules

from sentence_transformers import SentenceTransformer
import torch
from transformers import BertTokenizer, BertModel
import pickle, pathlib, re, os
import numpy as np
import keras
from keras import models
from keras import layers
from keras.models import Sequential

# %%
#check if GPU is available 
#set device, we need this later to push our model and the data to the GPU to perform computations

if torch.cuda.is_available(): 
    device = torch.device("cuda:1") 
    print(f'There are {torch.cuda.device_count()} GPU(s) available.')
    print('Device name:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 3 GPU(s) available.
# Device name: Quadro RTX 5000

# %%
from transformers import BertTokenizer

# Load the BERT tokenizer.
print('Loading BERT tokenizer...')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

# Load pre-trained model (weights)
model = BertModel.from_pretrained('bert-base-uncased',
                                  output_hidden_states = True, # For the model to returns all hidden-states.
                                  ).to(device) #push the model into the gpu.

# Put the model in "evaluation" mode, meaning feed-forward operation.
model.eval()
# Out:
# Loading BERT tokenizer...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 768, padding_idx=0)
#     (position_embeddings): Embedding(512, 768)
#     (token_type_embeddings): Embedding(2, 768)
#     (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): BertLayer(
#         (attention): BertAttention(
#           (self): BertSelfAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=768, out_features=768, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
# get embeddings for all words in sentences
def emb_func(sentences):
    
    # Add the special tokens with encode plus.
    encoding = tokenizer.encode_plus(sentences, add_special_tokens = True, truncation=True, padding=True,return_attention_mask= True, return_tensors="pt") 

    tokens_tensor = encoding["input_ids"] 
    segments_tensors = encoding["attention_mask"] 
    segments_ids = encoding["token_type_ids"]
    
    with torch.no_grad():

        outputs = model(tokens_tensor.to(device), segments_tensors.to(device)) #fit the vectors into the moedel

    hidden_states = outputs[2] #extraction of hidden states
    
    
    del outputs   #free gpu --- freeing GPU we avoid CUDA out of memory problem on the server.
    

    token_embeddings = torch.stack(hidden_states, dim=0) #torch.Size([13, 1, 73, 768])
    
    token_embeddings = torch.squeeze(token_embeddings, dim=1) #torch.Size([13, 73, 768])
    
    token_embeddings = token_embeddings.permute(1,0,2) #torch.Size([73, 13, 768])
    
    #Extracting CLS embedding
    cls_emb = token_embeddings[0][-4:].mean(dim=0).detach().cpu().numpy() #Extraction of CLS embeddings

    # Alternatively we store the token vectors
    sent_token_vecs_avg = []

    # For each token in the sentence...
    for token in token_embeddings:
        tok = token.to("cpu")   #feed into a cpu
        token.detach() #deletion of the token in GPU 
        del token  

        # Average last four layers.
        sum_vec = torch.mean(tok[-4:], dim=0)
    
        sent_token_vecs_avg.append(sum_vec)

    b_emb = torch.stack(sent_token_vecs_avg, dim=0).mean(dim=0).detach().cpu().numpy() #Extraction of the summed embeddings
        
    return b_emb, cls_emb

# %%
#Preparing the inputs for the embedding function

text_list = final_df.text.values.tolist()
labels_list = final_df.character.values.tolist()
#print(text_list[:10])
#print(labels_list[:10])
#type(text_list[0])

# %%
# !pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in /usr/lib/python3.6/site-packages (4.45.0)

# %%
"""Function that takes a list of sentences as inputs,
calls the function for embedding extraction and return two list
with sentence and cls embeddings"""

def run_embedding_function(text_list):
    #empty lists for embeddings
    avg_embeddings = []
    cls_embeddings = []
    
    #loop for iteration
    for idx in tqdm(range(0, len(text_list)), desc ="Creating sentence embeddings"):

        b_emb, cls_emb = emb_func(text_list[idx])
        avg_embeddings.append(b_emb)
        cls_embeddings.append(cls_emb)
        
    return avg_embeddings, cls_embeddings

# %%
embeddings1 = run_embedding_function(text_list)
# Out:
# Creating sentence embeddings: 100%|██████████| 84427/84427 [13:59<00:00, 100.58it/s]

# %%
avg_embeddings = embeddings1[0]
cls_embeddings = embeddings1[1]

# %%
# #Saving Embeddings
with open('avg_embeddings.pkl', 'wb') as handle:
    pickle.dump(avg_embeddings, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
with open('cls_embeddings.pkl', 'wb') as handle:
    pickle.dump(cls_embeddings, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#Loading Embeddings
with open('avg_embeddings.pkl', 'rb') as handle:
    avg_embeddings = pickle.load(handle)

with open('cls_embeddings.pkl', 'rb') as handle:
    cls_embeddings = pickle.load(handle)

# %% [markdown]
# # Step 3: Multi-class classification
#
# As our aim is to predict the character of a sentence, our task is a supervised Multi-Class Classification one where we will train a model with labeled data (name of characters). In our first step we use the averaged embeddings we extracted in the previous step to build and try our models, afterwards we are going to try building our models with the cls embeddings.
#
# We split our data into 80% training and 20% test data.

# %% [markdown]
# ### 1) Classification with averaged embeddings

# %%
#arrange indices 
indices = np.arange(np.array(avg_embeddings).shape[0])
np.random.shuffle(indices)

avg_embeddings, labels = np.array(avg_embeddings), np.array(labels_list) #transforming embeddings and labels into numpy array

avg_embeddings = avg_embeddings[indices]
labels_list = labels[indices]
labels_list = np.unique(labels_list, return_inverse=True)[1]

# %%
#Define train and test set
training_samples = (max(indices) * 80)//100 #setting training set to 80% of data

x_train = avg_embeddings[:training_samples]
y_train = labels_list[:training_samples]

x_test = avg_embeddings[training_samples:]
y_test = labels_list[training_samples:]

# %%
# convert to categorical labels
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### > 1st Model - One simple layer
#
# - Our first model contains of one simple layer
# - We use 'adamax' optimizer
# - our input layer has half of the nodes as the output layer
# - the output layer consists of 14 nodes since we have 14 characters to we decided to include in the analysis

# %%
# Defining the model
model = Sequential()
#input layer with half nodes as output layer
model.add(layers.Dense(len(set(labels))/2, activation='relu', input_shape=(768,))) 

#output with 14 nodes as 14 characters to analize
model.add(layers.Dense(len(set(labels)), activation='softmax')) 

model.compile(optimizer='adamax', loss='categorical_crossentropy', metrics=['acc'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 7)                 5383
# _________________________________________________________________
# dense_1 (Dense)              (None, 14)                112
# =================================================================
# Total params: 5,495
# Trainable params: 5,495
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train,
                            epochs=12,
                            batch_size=64,
                            validation_split=0.2)
model.save_weights('tsm1.h5')
# Out:
# Epoch 1/12
# 845/845 [==============================] - 1s 1ms/step - loss: 2.0823 - acc: 0.3300 - val_loss: 2.0032 - val_acc: 0.3389
# Epoch 2/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.9895 - acc: 0.3453 - val_loss: 1.9730 - val_acc: 0.3528
# Epoch 3/12
# 845/845 [==============================] - 1s 947us/step - loss: 1.9588 - acc: 0.3561 - val_loss: 1.9484 - val_acc: 0.3588
# Epoch 4/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.9299 - acc: 0.3626 - val_loss: 1.9297 - val_acc: 0.3624
# Epoch 5/12
# 845/845 [==============================] - 1s 996us/step - loss: 1.9069 - acc: 0.3684 - val_loss: 1.9120 - val_acc: 0.3711
# Epoch 6/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8906 - acc: 0.3719 - val_loss: 1.9010 - val_acc: 0.3727
# Epoch 7/12
# 845/845 [==============================] - 1s 985us/step - loss: 1.8784 - acc: 0.3759 - val_loss: 1.8933 - val_acc: 0.3755
# Epoch 8/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8683 - acc: 0.3798 - val_loss: 1.8852 - val_acc: 0.3790
# Epoch 9/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8593 - acc: 0.3851 - val_loss: 1.8798 - val_acc: 0.3812
# Epoch 10/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8515 - acc: 0.3865 - val_loss: 1.8763 - val_acc: 0.3816
# Epoch 11/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8452 - acc: 0.3887 - val_loss: 1.8711 - val_acc: 0.3849
# Epoch 12/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8396 - acc: 0.3908 - val_loss: 1.8688 - val_acc: 0.3867

# %%
#plotting performance of Model 1

import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy Model 1\n 1 Layer 12 epochs')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model.load_weights("tsm1.h5")
model.evaluate(x_test, y_test)
# Out:
# 528/528 [==============================] - 0s 548us/step - loss: 1.8665 - acc: 0.3792
# [1.8664613962173462, 0.3791674077510834]

# %% [markdown]
# The accuracy of our first model is at ~38%. We try and improve that in the following models.

# %% [markdown]
# ____________
# ### > 2nd Model
# - second model with 'rmsprop' optimizer and one layer
# - rest of the parameters equal to Model 1

# %%
# Defining the model
model2 = Sequential()

#input layer with half nodes as output layer
model2.add(layers.Dense(len(set(labels))/2, activation='relu', input_shape=(768,))) 

#output with 14 nodes as 14 characters to analize
model2.add(layers.Dense(len(set(labels)), activation='softmax')) 


model2.compile(optimizer='rmsprop',
               loss='categorical_crossentropy',
               metrics=['acc'])
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 7)                 5383
# _________________________________________________________________
# dense_3 (Dense)              (None, 14)                112
# =================================================================
# Total params: 5,495
# Trainable params: 5,495
# Non-trainable params: 0
# _________________________________________________________________

# %%
history2 = model2.fit(x_train, y_train,
                            epochs=12,
                            batch_size=64,
                            validation_split=0.2)

model2.save_weights('tsm2.h5')
# Out:
# Epoch 1/12
# 845/845 [==============================] - 1s 1ms/step - loss: 2.0162 - acc: 0.3418 - val_loss: 1.9622 - val_acc: 0.3509
# Epoch 2/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.9271 - acc: 0.3694 - val_loss: 1.9193 - val_acc: 0.3737
# Epoch 3/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8998 - acc: 0.3763 - val_loss: 1.9087 - val_acc: 0.3686
# Epoch 4/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8804 - acc: 0.3811 - val_loss: 1.8938 - val_acc: 0.3777
# Epoch 5/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8668 - acc: 0.3850 - val_loss: 1.8906 - val_acc: 0.3777
# Epoch 6/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8563 - acc: 0.3871 - val_loss: 1.8816 - val_acc: 0.3804
# Epoch 7/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8486 - acc: 0.3898 - val_loss: 1.8792 - val_acc: 0.3841
# Epoch 8/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8428 - acc: 0.3913 - val_loss: 1.8741 - val_acc: 0.3841
# Epoch 9/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8381 - acc: 0.3924 - val_loss: 1.8687 - val_acc: 0.3851
# Epoch 10/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8342 - acc: 0.3932 - val_loss: 1.8765 - val_acc: 0.3830
# Epoch 11/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8302 - acc: 0.3944 - val_loss: 1.8882 - val_acc: 0.3801
# Epoch 12/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8274 - acc: 0.3958 - val_loss: 1.8748 - val_acc: 0.3823

# %%
model2.load_weights("tsm2.h5")
model2.evaluate(x_test, y_test)
# Out:
# 528/528 [==============================] - 0s 526us/step - loss: 1.8738 - acc: 0.3844
# [1.8737640380859375, 0.3843785226345062]

# %% [markdown]
# No much difference when changing the optimizer function, so let's play with the numer of layers/nodes and using 'adamax' as it has a slightly better performance.

# %% [markdown]
# ### > 3rd Model - Adding 2 layers and using adamax

# %%
# Defining the model
model3 = Sequential()

#input layer with half nodes as output layer
model3.add(layers.Dense(len(set(labels))/2, activation='relu', input_shape=(768,))) 
model3.add(layers.Dense(len(set(labels))/2, activation='relu'))
model3.add(layers.Dense(len(set(labels))/2, activation='relu'))

#output with 14 nodes as 14 characters to analize
model3.add(layers.Dense(len(set(labels)), activation='softmax')) 

model3.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc']) #INITIALLY USED ADAMAX
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 7)                 5383
# _________________________________________________________________
# dense_5 (Dense)              (None, 7)                 56
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 56
# _________________________________________________________________
# dense_7 (Dense)              (None, 14)                112
# =================================================================
# Total params: 5,607
# Trainable params: 5,607
# Non-trainable params: 0
# _________________________________________________________________

# %%
history3 = model3.fit(x_train, y_train,
                            epochs=12,
                            batch_size=64,
                            validation_split=0.2)
model3.save_weights('tsm3.h5')
# Out:
# Epoch 1/12
# 845/845 [==============================] - 2s 1ms/step - loss: 2.0724 - acc: 0.3229 - val_loss: 1.9847 - val_acc: 0.3544
# Epoch 2/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.9458 - acc: 0.3621 - val_loss: 1.9497 - val_acc: 0.3629
# Epoch 3/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.9077 - acc: 0.3760 - val_loss: 1.9267 - val_acc: 0.3683
# Epoch 4/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8891 - acc: 0.3798 - val_loss: 1.8995 - val_acc: 0.3759
# Epoch 5/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8765 - acc: 0.3838 - val_loss: 1.8944 - val_acc: 0.3784
# Epoch 6/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8687 - acc: 0.3874 - val_loss: 1.9016 - val_acc: 0.3653
# Epoch 7/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8619 - acc: 0.3895 - val_loss: 1.8927 - val_acc: 0.3768
# Epoch 8/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8577 - acc: 0.3900 - val_loss: 1.8882 - val_acc: 0.3794
# Epoch 9/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8531 - acc: 0.3909 - val_loss: 1.8873 - val_acc: 0.3826
# Epoch 10/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8499 - acc: 0.3924 - val_loss: 1.8862 - val_acc: 0.3838
# Epoch 11/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8472 - acc: 0.3922 - val_loss: 1.8797 - val_acc: 0.3835
# Epoch 12/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8450 - acc: 0.3936 - val_loss: 1.8924 - val_acc: 0.3684

# %%
model3.load_weights("tsm3.h5")
model3.evaluate(x_test, y_test)
# Out:
# 528/528 [==============================] - 0s 548us/step - loss: 1.8893 - acc: 0.3706
# [1.8893107175827026, 0.3706401288509369]

# %% [markdown]
# **Okay, so the model doesnt improve with 2 more layers, let's try changing the nodes.**

# %% [markdown]
# ### > 4th Model - 2 layers and double amount of nodes (adamax optimizer)

# %%
# Defining the model
model4 = Sequential()
model4.add(layers.Dense(len(set(labels))*2, activation='relu', input_shape=(768,)))
model4.add(layers.Dense(len(set(labels))*2, activation='relu'))

model4.add(layers.Dense(len(set(labels)), activation='softmax'))

model4.compile(optimizer='adamax', loss='categorical_crossentropy', metrics=['acc']) #INITIALLY USED ADAMAX
model4.summary()

history = model4.fit(x_train, y_train,
                            epochs=12,
                            batch_size=64,   #INITIALLY 32
                            validation_split=0.2)
model4.save_weights('tsm4.h5')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 28)                21532
# _________________________________________________________________
# dense_9 (Dense)              (None, 28)                812
# _________________________________________________________________
# dense_10 (Dense)             (None, 14)                406
# =================================================================
# Total params: 22,750
# Trainable params: 22,750
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/12
# 845/845 [==============================] - 1s 1ms/step - loss: 2.0268 - acc: 0.3403 - val_loss: 1.9464 - val_acc: 0.3637
# Epoch 2/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.9193 - acc: 0.3690 - val_loss: 1.9072 - val_acc: 0.3721
# Epoch 3/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8802 - acc: 0.3809 - val_loss: 1.8856 - val_acc: 0.3811
# Epoch 4/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8544 - acc: 0.3876 - val_loss: 1.8719 - val_acc: 0.3872
# Epoch 5/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8355 - acc: 0.3928 - val_loss: 1.8578 - val_acc: 0.3893
# Epoch 6/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8192 - acc: 0.3971 - val_loss: 1.8562 - val_acc: 0.3872
# Epoch 7/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.8043 - acc: 0.4014 - val_loss: 1.8467 - val_acc: 0.3898
# Epoch 8/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.7920 - acc: 0.4075 - val_loss: 1.8393 - val_acc: 0.3933
# Epoch 9/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.7816 - acc: 0.4104 - val_loss: 1.8348 - val_acc: 0.3918
# Epoch 10/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.7707 - acc: 0.4131 - val_loss: 1.8387 - val_acc: 0.3878
# Epoch 11/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.7614 - acc: 0.4158 - val_loss: 1.8288 - val_acc: 0.3994
# Epoch 12/12
# 845/845 [==============================] - 1s 1ms/step - loss: 1.7541 - acc: 0.4179 - val_loss: 1.8318 - val_acc: 0.3895

# %%
model4.load_weights("tsm4.h5")
model4.evaluate(x_test, y_test)
# Out:
# 528/528 [==============================] - 0s 561us/step - loss: 1.8266 - acc: 0.3901
# [1.8266085386276245, 0.3900633752346039]

# %% [markdown]
# **Almost 40% of accuracy with 2 layers and 28 nodes in their hidden layers**

# %% [markdown]
# ### Model 4 with CLS embeddings
# As the other models had very low accuracy we will see how the model behaves if we use the CLS embeddings instead of the sentence embedding to check if the results are better.

# %%
#arrange indices 
indices = np.arange(np.array(cls_embeddings).shape[0])
np.random.shuffle(indices)

cls_embeddings, labels = np.array(cls_embeddings), np.array(labels_list) #transforming into numpy array

cls_embeddings = cls_embeddings[indices]
labels_list = labels[indices]
labels_list = np.unique(labels_list, return_inverse=True)[1]

# %%
#Define train and test set
training_samples_cls = (max(indices) * 80)//100 #setting training samples to 80%
validation_samples = int(0.10*(len(cls_embeddings))) #10% as validation samples

x_train_cls = cls_embeddings[:training_samples]
y_train_cls = labels_list[:training_samples]

x_test_cls = cls_embeddings[training_samples:]
y_test_cls = labels_list[training_samples:]

# %%
# convert to categorical labels
from tensorflow.keras.utils import to_categorical

y_train_cls = to_categorical(y_train_cls)
y_test_cls = to_categorical(y_test_cls)

# %%
# Defining the model

model_cls = Sequential()

#input layer with half nodes as output layer
model_cls.add(layers.Dense(len(set(labels))/2, activation='relu', input_shape=(768,))) 

#output with 14 nodes as 14 characters to analize
model_cls.add(layers.Dense(len(set(labels)), activation='softmax')) 

model_cls.compile(optimizer='adamax', loss='categorical_crossentropy', metrics=['acc']) #INITIALLY USED ADAMAX
model_cls.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 7)                 5383
# _________________________________________________________________
# dense_12 (Dense)             (None, 14)                112
# =================================================================
# Total params: 5,495
# Trainable params: 5,495
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_cls = model_cls.fit(x_train_cls, y_train_cls,
                            epochs=12,
                            batch_size=64,
                            validation_split=0.2)
model_cls.save_weights('tscls.h5')
# Out:
# Epoch 1/12
# 845/845 [==============================] - 1s 1ms/step - loss: 2.1597 - acc: 0.2875 - val_loss: 2.0772 - val_acc: 0.3288
# Epoch 2/12
# 845/845 [==============================] - 1s 1ms/step - loss: 2.0720 - acc: 0.3301 - val_loss: 2.0752 - val_acc: 0.3288
# Epoch 3/12
# 845/845 [==============================] - 1s 1ms/step - loss: 2.0699 - acc: 0.3301 - val_loss: 2.0758 - val_acc: 0.3288
# Epoch 4/12
# 845/845 [==============================] - 1s 1ms/step - loss: 2.0686 - acc: 0.3302 - val_loss: 2.0782 - val_acc: 0.3288
# Epoch 5/12
# 845/845 [==============================] - 1s 1ms/step - loss: 2.0677 - acc: 0.3301 - val_loss: 2.0753 - val_acc: 0.3288
# Epoch 6/12
# 845/845 [==============================] - 1s 1ms/step - loss: 2.0666 - acc: 0.3302 - val_loss: 2.0771 - val_acc: 0.3287
# Epoch 7/12
# 845/845 [==============================] - 1s 981us/step - loss: 2.0658 - acc: 0.3302 - val_loss: 2.0762 - val_acc: 0.3286
# Epoch 8/12
# 845/845 [==============================] - 1s 985us/step - loss: 2.0653 - acc: 0.3303 - val_loss: 2.0766 - val_acc: 0.3288
# Epoch 9/12
# 845/845 [==============================] - 1s 1ms/step - loss: 2.0648 - acc: 0.3303 - val_loss: 2.0772 - val_acc: 0.3288
# Epoch 10/12
# 845/845 [==============================] - 1s 1ms/step - loss: 2.0638 - acc: 0.3303 - val_loss: 2.0803 - val_acc: 0.3288
# Epoch 11/12
# 845/845 [==============================] - 1s 1ms/step - loss: 2.0628 - acc: 0.3304 - val_loss: 2.0756 - val_acc: 0.3288
# Epoch 12/12
# 845/845 [==============================] - 1s 972us/step - loss: 2.0628 - acc: 0.3304 - val_loss: 2.0761 - val_acc: 0.3287

# %%
model_cls.load_weights("tscls.h5")
model_cls.evaluate(x_test_cls, y_test_cls)
# Out:
# 528/528 [==============================] - 0s 514us/step - loss: 2.0862 - acc: 0.3297
# [2.0861752033233643, 0.32966187596321106]

# %% [markdown]
# **This last model performs the worst **

# %% [markdown]
# ************
# ************

# %% [markdown]
# ## Second part: Clustering sentences
#
# Well as we can see the networks models we built have very low accuracy, so we will try to build clusters (non supervised task) to check if we are able to differentiate the sentences per character.
#
# To simplify this task we will work only with The Simpsons family members (Homer, Marge, Bart and Lisa).

# %% [markdown]
# ## Step 1: clustering with kmeans

# %%
from sklearn.cluster import KMeans
from sentence_transformers import SentenceTransformer
from sklearn import preprocessing

# %% [markdown]
# ___________
# ### Data reduction and embedding extraction
# _________

# %%
final_df.character.value_counts()
# Out:
# Homer Simpson          27850
# Marge Simpson          13172
# Bart Simpson           12995
# Lisa Simpson           10756
# C. Montgomery Burns     3077
# Moe Szyslak             2808
# Seymour Skinner         2385
# Ned Flanders            2056
# Grampa Simpson          1802
# Chief Wiggum            1790
# Milhouse Van Houten     1750
# Krusty the Clown        1699
# Lenny Leonard           1144
# Nelson Muntz            1143
# Name: character, dtype: int64

# %%
#Filter Simpsons family
final_df2 = final_df.loc[final_df['count'] >= 10756]

# %%
len_ = len(final_df2['text'])
len_1 = len(df['text'])
print('-------')
print(f'We will work with {len_} dialogues which corresponds to a {format(((len_/len_1)*100),".2f")} % of the original dataset') 
print('-------')
# Out:
# -------
# We will work with 64773 dialogues which corresponds to a 49.13 % of the original dataset
# -------

# %%
sentences2 = final_df2['text'].tolist()
type(sentences2)
# Out:
# list

# %%
text_list2 = final_df2.text.values.tolist()
labels_list = final_df.character.values.tolist()

# %%
#Generating embeddings
embeddings2 = run_embedding_function(text_list2)
# Out:
# Creating sentence embeddings: 100%|██████████| 64773/64773 [10:31<00:00, 102.60it/s]

# %%
fam_avg_embeddings = embeddings2[0] #We are only interested on these embeddings

# %%
# #Saving Embeddings
with open('fam_embeddings.pkl', 'wb') as handle:
    pickle.dump(fam_avg_embeddings, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#Loading Embeddings
with open('fam_embeddings.pkl', 'rb') as handle:
    fam_embeddings = pickle.load(handle)

# %% [markdown]
# _____________________
# By default kmeans works with euclidean distance, which is not the best option as we are working in a very high dimensional space and as 'curse of dimensionality' the distance will be very big between sentences if we use this metric. Therefore we need to normalize using cosine similarity (angular distance).
# _______________

# %%
##kmeans uses euclidean distance by default so in this step we normalize to unit vectors
bert_norm = preprocessing.normalize(fam_avg_embeddings, norm='l2') 
#bert_norm

bert_list = bert_norm.tolist() #for input to kmeans
type(bert_list)
# Out:
# list

# %%
#Clustering process
k=4 #as 4 family members

#initializing model
kmeans_bert = KMeans(n_clusters = k, algorithm = 'auto')

#fitting the model
fit_bert = kmeans_bert.fit(bert_list)

#predicting step
predict_bert = kmeans_bert.predict(bert_list)

# %%
final_df2['ClusterID_BERT'] = kmeans_bert.labels_

final_df2.head()
# Out:
# /usr/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        character                                 text  count  ClusterID_BERT
# 1   Lisa Simpson               Where's Mr. Bergstrom?  10756               1
# 3   Lisa Simpson           That life is worth living.  10756               3
# 7   Bart Simpson       Victory party under the slide!  12995               0
# 8   Lisa Simpson        Mr. Bergstrom! Mr. Bergstrom!  10756               0
# 10  Lisa Simpson  Do you know where I could find him?  10756               1

# %%
cluster_0 = final_df2[final_df2['ClusterID_BERT'] == 0] 
cluster_1 = final_df2[final_df2['ClusterID_BERT'] == 1] 
cluster_2 = final_df2[final_df2['ClusterID_BERT'] == 2]
cluster_3 = final_df2[final_df2['ClusterID_BERT'] == 3]

# %% [markdown]
# ____________
#
# ### The Simpsons clusters wordclouds
# __________

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
#Cluster 0
all_words = ' '.join([text for text in cluster_0['text']])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110,max_words=100).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
#Cluster 1
all_words = ' '.join([text for text in cluster_1['text']])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110,max_words=100).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
#Cluster 2
all_words = ' '.join([text for text in cluster_2['text']])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110,max_words=100).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
#Cluster 3
all_words = ' '.join([text for text in cluster_3['text']])
wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110, max_words=100).generate(all_words)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# All four clusters look quite similar, so the sentence model doesnt really differentiate by character. We can see that most of the characters talk about simmilar things on they dialogues.

# %% [markdown]
# ________________
# ### Step 2: clustering with hdbscan
# _________________
#
# As the last clustering method did not work very well we will try to see if HDBSCAN (density based algorithm) is more capable to detect differences between characters depending on their dialogues as the number of clusters does not need to be determined in advances.
#
# For this task we will do Topic Analysis with a pretrained sentence bert model and extract clusters using umap for dimensionality reduction and HDBSCAN as clustering method.

# %%
pip install umap-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      |████████████████████████████████| 88 kB 6.6 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from umap-learn) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/lib64/python3.6/site-packages (from umap-learn) (0.23.2)
# Requirement already satisfied: scipy>=1.0 in /usr/lib64/python3.6/site-packages (from umap-learn) (1.3.3)
# Collecting numba>=0.49
#   Downloading numba-0.53.1-cp36-cp36m-manylinux2014_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 21.0 MB/s
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.7.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 50.8 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/lib/python3.6/site-packages (from umap-learn) (4.45.0)
# Requirement already satisfied: setuptools in /usr/lib/python3.6/site-packages (from numba>=0.49->umap-learn) (57.4.0)
# Collecting llvmlite<0.37,>=0.36.0rc1
#   Downloading llvmlite-0.36.0-cp36-cp36m-manylinux2010_x86_64.whl (25.3 MB)
#      |████████████████████████████████| 25.3 MB 100.6 MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/lib/python3.6/site-packages (from pynndescent>=0.5->umap-learn) (0.16.0)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=5bdbced7233886274e1e3f47a4bcba607a79817d0733d32194437ca58cb01591
#   Stored in directory: /export/home/trinidad.bosch-achondo/.cache/pip/wheels/54/ca/cf/35a4f9a744b0bce9549e4e492261bef3903434d0118f3ee858
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.7-py3-none-any.whl size=54286 sha256=23c31af86ad1dbd713cffb002456e7b954054ead219773fc95720047734b7116
#   Stored in directory: /export/home/trinidad.bosch-achondo/.cache/pip/wheels/fd/8a/9e/58bdbe4211581dd2aeffe2ce46020a000bf67127afac24e772
# Successfully built umap-learn pynndescent
# Installing collected packages: llvmlite, numba, pynndescent, umap-learn
# Successfully installed llvmlite-0.36.0 numba-0.53.1 pynndescent-0.5.7 umap-learn-0.5.3
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install hdbscan
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting hdbscan
#   Downloading hdbscan-0.8.28.tar.gz (5.2 MB)
#      |████████████████████████████████| 5.2 MB 8.8 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Downloading hdbscan-0.8.27.tar.gz (6.4 MB)
#      |████████████████████████████████| 6.4 MB 43.3 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cython>=0.27 in /usr/lib64/python3.6/site-packages (from hdbscan) (0.29.14)
# Requirement already satisfied: six in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from hdbscan) (1.15.0)
# Requirement already satisfied: scipy>=1.0 in /usr/lib64/python3.6/site-packages (from hdbscan) (1.3.3)
# Collecting joblib>=1.0
#   Downloading joblib-1.1.0-py2.py3-none-any.whl (306 kB)
#      |████████████████████████████████| 306 kB 75.4 MB/s
# Requirement already satisfied: scikit-learn>=0.20 in /usr/lib64/python3.6/site-packages (from hdbscan) (0.23.2)
# Requirement already satisfied: numpy>=1.16 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from hdbscan) (1.19.5)
# Building wheels for collected packages: hdbscan
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.27-cp36-cp36m-linux_x86_64.whl size=2318813 sha256=e7081a93e4d7b7c1459d9611444844a2870e573004851bdb9ba24a5841546089
#   Stored in directory: /export/home/trinidad.bosch-achondo/.cache/pip/wheels/70/52/fe/83ef5a0e879c48df9968d931d41046226e4cb19a166f0223d2
# Successfully built hdbscan
# Installing collected packages: joblib, hdbscan
# Successfully installed hdbscan-0.8.27 joblib-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bertopic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting bertopic
#   Downloading bertopic-0.9.3-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 4.9 MB/s
# Requirement already satisfied: tqdm>=4.41.1 in /usr/lib/python3.6/site-packages (from bertopic) (4.45.0)
# Requirement already satisfied: hdbscan>=0.8.27 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from bertopic) (0.8.27)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from bertopic) (2.2.2)
#   Downloading bertopic-0.9.2-py2.py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 7.6 MB/s
#   Downloading bertopic-0.9.1-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 8.3 MB/s
#   Downloading bertopic-0.9.0-py2.py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 5.4 MB/s
#   Downloading bertopic-0.8.1-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 5.0 MB/s
#   Downloading bertopic-0.8.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 3.0 MB/s
#   Downloading bertopic-0.7.0-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 6.8 MB/s
#   Downloading bertopic-0.6.0-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: torch>=1.4.0 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from bertopic) (1.10.1)
# Collecting pandas>=1.1.5
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 45.2 MB/s
# Requirement already satisfied: numpy>=1.19.2 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from bertopic) (1.19.5)
# Requirement already satisfied: umap-learn>=0.5.0 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from bertopic) (0.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/lib64/python3.6/site-packages (from bertopic) (0.23.2)
# Requirement already satisfied: six in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from hdbscan>=0.8.27->bertopic) (1.15.0)
# Requirement already satisfied: cython>=0.27 in /usr/lib64/python3.6/site-packages (from hdbscan>=0.8.27->bertopic) (0.29.14)
# Requirement already satisfied: scipy>=1.0 in /usr/lib64/python3.6/site-packages (from hdbscan>=0.8.27->bertopic) (1.3.3)
# Requirement already satisfied: joblib>=1.0 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from hdbscan>=0.8.27->bertopic) (1.1.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/lib/python3.6/site-packages (from pandas>=1.1.5->bertopic) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/lib/python3.6/site-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: sentencepiece in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.97)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.18.0)
# Requirement already satisfied: torchvision in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.11.2)
# Requirement already satisfied: nltk in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from sentence-transformers>=0.4.1->bertopic) (3.6.7)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.4.0)
# Requirement already satisfied: dataclasses in /usr/lib/python3.6/site-packages (from torch>=1.4.0->bertopic) (0.8)
# Requirement already satisfied: typing-extensions in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from torch>=1.4.0->bertopic) (3.7.4.3)
# Requirement already satisfied: numba>=0.49 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from umap-learn>=0.5.0->bertopic) (0.53.1)
# Requirement already satisfied: pynndescent>=0.5 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from umap-learn>=0.5.0->bertopic) (0.5.7)
# Requirement already satisfied: importlib-metadata in /usr/lib/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.6.3)
# Requirement already satisfied: requests in /usr/lib/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.26.0)
# Requirement already satisfied: packaging>=20.9 in /usr/lib/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (21.0)
# Requirement already satisfied: pyyaml in /usr/lib64/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (5.4.1)
# Requirement already satisfied: filelock in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.4.1)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.36.0)
# Requirement already satisfied: setuptools in /usr/lib/python3.6/site-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (57.4.0)
# Requirement already satisfied: sacremoses in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.0.53)
# Requirement already satisfied: regex!=2019.12.17 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.6.2)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /export/home/trinidad.bosch-achondo/.local/lib/python3.6/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.12.1)
# Requirement already satisfied: click in /usr/lib/python3.6/site-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (7.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/lib64/python3.6/site-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.3.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/lib/python3.6/site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.4.7)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3.6/site-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.5.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/lib/python3.6/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3.6/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2021.5.30)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.6/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/lib/python3.6/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.6)
# Installing collected packages: pandas, bertopic
# Successfully installed bertopic-0.6.0 pandas-1.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import umap #for dimension reduction
from bertopic import BERTopic #topic model
from sklearn.feature_extraction.text import CountVectorizer
import hdbscan #for clustering

# %%
# Define UMAP model to reduce embeddings dimension
umap_model = umap.UMAP(n_neighbors=15,
                       n_components=10,
                       min_dist=0.0,
                       metric='cosine',
                       low_memory=False)

# Define HDBSCAN model to perform documents clustering
#min_cluster_size tried different parameters, with n=50 was retrieving more than 200 clusters
hdbscan_model = hdbscan.HDBSCAN(min_cluster_size=200, 
                                min_samples=1,
                                metric='euclidean',
                                cluster_selection_method='eom',
                                prediction_data=True)

# %%
#for stopword removal, first iteration without removing them retrieved topics with no much meaning
vectorizer_model = CountVectorizer(ngram_range=(1, 2), stop_words="english") 

model = BERTopic(
    vectorizer_model=vectorizer_model,
    language='english',
    calculate_probabilities=True,
    verbose=True,
    umap_model= umap_model,
    hdbscan_model=hdbscan_model,
    )

# %%
fam_avg_embeddings = np.array(fam_avg_embeddings) ## transform to array for input
topics, probabilities = model.fit_transform(text_list2, fam_avg_embeddings)
# Out:
# 2022-08-22 10:46:42,104 - BERTopic - Reduced dimensionality with UMAP
# 2022-08-22 10:47:00,124 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
model.get_topic_freq()
# Out:
#    Topic  Count
# 0      2  60200
# 1     -1   3844
# 2      1    491
# 3      0    238

# %%
# topic '-1' is considered the outlier cluster and can be taken away of the analysis
model.get_topic(0)
# Out:
# [('really', 0.41207653195931854),
#  ('oh really', 0.22994134248862694),
#  ('like', 0.211897694990632),
#  ('really like', 0.19616877235487828),
#  ('oh', 0.1744456870830522),
#  ('huh', 0.13089685975771426),
#  ('like oh', 0.11654111171973193),
#  ('glum', 0.09978213358904794),
#  ('like really', 0.08641255672881439),
#  ('happened', 0.08617754791960185),
#  ('come oh', 0.08129820877411606),
#  ('really really', 0.07733121230630789),
#  ('huh oh', 0.0769825837449454),
#  ('come', 0.06442532366423016),
#  ('proud', 0.063537356309886),
#  ('proud proud', 0.05297172093034595),
#  ('said sir', 0.05297172093034595),
#  ('whatwhat like', 0.05297172093034595),
#  ('lenny reason', 0.05297172093034595),
#  ('proud lazar', 0.05297172093034595),
#  ('cares wait', 0.05297172093034595),
#  ('know grow', 0.05297172093034595),
#  ('look bout', 0.05297172093034595),
#  ('impossible guy', 0.05297172093034595),
#  ('really pictures', 0.05297172093034595),
#  ('yes pick', 0.05297172093034595),
#  ('quiet change', 0.05297172093034595),
#  ('missing guess', 0.05297172093034595),
#  ('really leslie', 0.05297172093034595),
#  ('happened started', 0.05297172093034595)]

# %% [markdown]
# Well as far as we can see here and with the kmeans cluster method, there are no really meaningfull groups from the dialogues. Maybe because the dialogues itself are not very meaningful??
